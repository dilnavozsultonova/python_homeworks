# %%
import pandas as pd

# %%
emp = pd.read_csv("data/employee.csv")
emp.head()
# Out:
#    UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                        Library
# 2          2               POLICE OFFICER  Houston Police Department-HPD
# 3          3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4          4                  ELECTRICIAN    General Services Department
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
# 2      45279.0            White       Full Time    Male            Active
# 3      63166.0            White       Full Time    Male            Active
# 4      56347.0            White       Full Time    Male            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18
# ...

# %%
emp["GENDER"]
# Out:
# 0       Female
# 1       Female
# 2         Male
# 3         Male
# 4         Male
#          ...
# 1995      Male
# 1996      Male
# 1997      Male
# 1998      Male
# 1999      Male
# Name: GENDER, Length: 2000, dtype: object

# %%
data = [
    ['John', 'Doe', 40],
    ['Jone', 'Doe', 44],
    ['Adam', 'Smith', 40],
]

columns = ['FirstName', 'LastName', 'Age']

df = pd.DataFrame(data=data, columns=columns)
df
# Out:
#   FirstName LastName  Age
# 0      John      Doe   40
# 1      Jone      Doe   44
# 2      Adam    Smith   40

# %%
emp.tail(2)
# Out:
#       UNIQUE_ID  POSITION_TITLE                     DEPARTMENT  BASE_SALARY  \
# 1998       1998  POLICE OFFICER  Houston Police Department-HPD      55461.0
# 1999       1999    FIRE FIGHTER  Houston Fire Department (HFD)      51194.0
#
#                         RACE EMPLOYMENT_TYPE GENDER EMPLOYMENT_STATUS  \
# 1998  Asian/Pacific Islander       Full Time   Male            Active
# 1999         Hispanic/Latino       Full Time   Male            Active
#
#        HIRE_DATE    JOB_DATE
# 1998  2009-01-20  2011-07-02
# 1999  2009-01-12  2010-07-12

# %%
emp.head(2)
# Out:
#    UNIQUE_ID               POSITION_TITLE                   DEPARTMENT  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)  Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                      Library
#
#    BASE_SALARY             RACE EMPLOYMENT_TYPE  GENDER EMPLOYMENT_STATUS  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
#
#     HIRE_DATE    JOB_DATE
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18

# %%
emp.sample(5)
# Out:
#       UNIQUE_ID                 POSITION_TITLE                     DEPARTMENT  \
# 1224       1224         MANAGEMENT ANALYST III    Housing and Community Devp.
# 1239       1239            ADMINISTRATIVE AIDE  Houston Police Department-HPD
# 1264       1264          SENIOR POLICE OFFICER  Houston Police Department-HPD
# 174         174                        LABORER   Houston Airport System (HAS)
# 1119       1119  HUMAN SERVICE PROGRAM MANAGER        Health & Human Services
#
#       BASE_SALARY                       RACE EMPLOYMENT_TYPE  GENDER  \
# 1224      54332.0                      White       Full Time  Female
# 1239      26229.0  Black or African American       Full Time  Female
# 1264      61643.0  Black or African American       Full Time  Female
# 174       26125.0  Black or African American       Full Time    Male
# 1119      63785.0                     Others       Full Time  Female
#
#      EMPLOYMENT_STATUS   HIRE_DATE    JOB_DATE
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   UNIQUE_ID          2000 non-null   int64
#  1   POSITION_TITLE     2000 non-null   object
#  2   DEPARTMENT         2000 non-null   object
#  3   BASE_SALARY        1886 non-null   float64
#  4   RACE               1965 non-null   object
#  5   EMPLOYMENT_TYPE    2000 non-null   object
#  6   GENDER             2000 non-null   object
#  7   EMPLOYMENT_STATUS  2000 non-null   object
#  8   HIRE_DATE          2000 non-null   object
#  9   JOB_DATE           1997 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 156.4+ KB

# %%
emp.describe()
# Out:
#          UNIQUE_ID    BASE_SALARY
# count  2000.000000    1886.000000
# mean    999.500000   55767.931601
# std     577.494589   21693.706679
# min       0.000000   24960.000000
# 25%     499.750000   40170.000000
# 50%     999.500000   54461.000000
# 75%    1499.250000   66614.000000
# max    1999.000000  275000.000000

# %%
len(emp)
# Out:
# 2000

# %%
emp.shape
# Out:
# (2000, 10)

# %%
new_columns = [column.lower() for column in emp.columns]
new_columns
# Out:
# ['unique_id',
#  'position_title',
#  'department',
#  'base_salary',
#  'race',
#  'employment_type',
#  'gender',
#  'employment_status',
#  'hire_date',
#  'job_date']

# %%
emp.columns = new_columns

# %%
emp.head(2)
# Out:
#    unique_id               position_title                   department  \
# 0          0  ASSISTANT DIRECTOR (EX LVL)  Municipal Courts Department
# 1          1            LIBRARY ASSISTANT                      Library
#
#    base_salary             race employment_type  gender employment_status  \
# 0     121862.0  Hispanic/Latino       Full Time  Female            Active
# 1      26125.0  Hispanic/Latino       Full Time  Female            Active
#
#     hire_date    job_date
# 0  2006-06-12  2012-10-13
# 1  2000-07-19  2010-09-18

# %%
emp.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
d = emp[["position_title","base_salary"]]
d
# Out:
#                    position_title  base_salary
# 0     ASSISTANT DIRECTOR (EX LVL)     121862.0
# 1               LIBRARY ASSISTANT      26125.0
# 2                  POLICE OFFICER      45279.0
# 3               ENGINEER/OPERATOR      63166.0
# 4                     ELECTRICIAN      56347.0
# ...                           ...          ...
# 1995               POLICE OFFICER      43443.0
# 1996       COMMUNICATIONS CAPTAIN      66523.0
# 1997               POLICE OFFICER      43443.0
# 1998               POLICE OFFICER      55461.0
# 1999                 FIRE FIGHTER      51194.0
#
# [2000 rows x 2 columns]

# %%
import numpy as np

# %%
emp["nimadir"] = np.where(emp["base_salary"] > 50000, "high", "low")
emp
# Out:
#       unique_id               position_title                     department  \
# 0             0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1             1            LIBRARY ASSISTANT                        Library
# 2             2               POLICE OFFICER  Houston Police Department-HPD
# 3             3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4             4                  ELECTRICIAN    General Services Department
# ...         ...                          ...                            ...
# 1995       1995               POLICE OFFICER  Houston Police Department-HPD
# 1996       1996       COMMUNICATIONS CAPTAIN  Houston Fire Department (HFD)
# 1997       1997               POLICE OFFICER  Houston Police Department-HPD
# 1998       1998               POLICE OFFICER  Houston Police Department-HPD
# 1999       1999                 FIRE FIGHTER  Houston Fire Department (HFD)
#
# ...

# %%
emp.drop(columns=["nimadir"], inplace=True)
emp
# Out:
#       unique_id               position_title                     department  \
# 0             0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1             1            LIBRARY ASSISTANT                        Library
# 2             2               POLICE OFFICER  Houston Police Department-HPD
# 3             3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4             4                  ELECTRICIAN    General Services Department
# ...         ...                          ...                            ...
# 1995       1995               POLICE OFFICER  Houston Police Department-HPD
# 1996       1996       COMMUNICATIONS CAPTAIN  Houston Fire Department (HFD)
# 1997       1997               POLICE OFFICER  Houston Police Department-HPD
# 1998       1998               POLICE OFFICER  Houston Police Department-HPD
# 1999       1999                 FIRE FIGHTER  Houston Fire Department (HFD)
#
# ...

# %%
emp.drop('nimadir', axis=1, inplace=True)
emp
# Out:
#       unique_id               position_title                     department  \
# 0             0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1             1            LIBRARY ASSISTANT                        Library
# 2             2               POLICE OFFICER  Houston Police Department-HPD
# 3             3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4             4                  ELECTRICIAN    General Services Department
# ...         ...                          ...                            ...
# 1995       1995               POLICE OFFICER  Houston Police Department-HPD
# 1996       1996       COMMUNICATIONS CAPTAIN  Houston Fire Department (HFD)
# 1997       1997               POLICE OFFICER  Houston Police Department-HPD
# 1998       1998               POLICE OFFICER  Houston Police Department-HPD
# 1999       1999                 FIRE FIGHTER  Houston Fire Department (HFD)
#
# ...

# %%
emp.query("base_salary<50000")
# Out:
#       unique_id                     position_title  \
# 1             1                  LIBRARY ASSISTANT
# 2             2                     POLICE OFFICER
# 7             7                          CARPENTER
# 9             9     AIRPORT OPERATIONS COORDINATOR
# 12           12  CUSTOMER SERVICE REPRESENTATIVE I
# ...         ...                                ...
# 1990       1990    BUILDING MAINTENANCE SUPERVISOR
# 1991       1991           MOBILITY SERVICE OFFICER
# 1992       1992                   SECURITY OFFICER
# 1995       1995                     POLICE OFFICER
# 1997       1997                     POLICE OFFICER
#
#                           department  base_salary                       race  \
# 1                            Library      26125.0            Hispanic/Latino
# 2      Houston Police Department-HPD      45279.0                      White
# 7       Houston Airport System (HAS)      42390.0                      White
# ...

# %%
emp.select_dtypes("number").sum()
# Out:
# unique_id        1999000.0
# base_salary    105178319.0
# dtype: float64
